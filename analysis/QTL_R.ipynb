# %%
library(tidyverse)
library(dplyr)
library(ggplot2)
library(bedr)
library(readr)
library(glue)
library(QCEWAS)
suppressMessages(library(tidyverse))
suppressMessages(library(data.table))
suppressMessages(library(data.table))
suppressMessages(library(bedtoolsr))
suppressMessages(library(GenomicRanges))
# Out:
# QCEWAS library, version 1.2-3
#
# A Quick Start Guide can be found in /home/cnajar/R/x86_64-pc-linux-gnu-library/4.1/QCEWAS/doc

# %%
tabix('chr1:16891930-16891932','../code/results/eqtl/GTEx/Liver/cis_100000/nom/chr1.txt.gz', verbose=FALSE)
# Out:
#   phe_id             phe_chr phe_from phe_to   phe_strd n_var_in_cis
# 1 ENSG00000058453.17 chr1    16740273 16972964 +        691
# 2 ENSG00000159363.18 chr1    16985958 17011928 -        697
#   dist_phe_var var_id                var_chr var_from var_to   nom_pval
# 1 0            chr1_16891931_C_G_b38 chr1    16891931 16891931 0.313762
# 2 94027        chr1_16891931_C_G_b38 chr1    16891931 16891931 0.939414
#   r_squared   slope      best_hit
# 1 0.00492589  0.284161   0
# 2 2.81116e-05 -0.0234421 0
