# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
exp_X = pd.read_csv('exp_X.tab', sep='\t')
up_X = pd.read_csv('up_X.tab', sep='\t')

# %%
counts = pd.read_csv('../code/analysis_files/GTEx.cluster_counts.tsv.gz', sep='\t')

# %%
counts
